# %%
import face_recognition
import time
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.

# %%
def mostrar_img(img):
    plt.imshow(img)
    plt.axis("off")  # Ocultar los ejes
    plt.show()

# %%
# Load the jpg files into numpy arrays
tiempo_open_img = []
inicio_tiempo = time.time()
biden_image = face_recognition.load_image_file("biden.jpg")
tiempo_open_img.append(time.time() - inicio_tiempo)
mostrar_img(biden_image)
inicio_tiempo = time.time()
obama_image = face_recognition.load_image_file("obama.jpg")
tiempo_open_img.append(time.time() - inicio_tiempo)
mostrar_img(obama_image)
inicio_tiempo = time.time()
unknown_image = face_recognition.load_image_file("obama2.jpg")
tiempo_open_img.append(time.time() - inicio_tiempo)
mostrar_img(unknown_image)
print(f"Tiempo promedio de lectura: {np.mean(tiempo_open_img)}")
# Out:
# Tiempo promedio de lectura: 0.023235400517781574

# %%
tiempo_encoding = []
biden_face_encoding = face_recognition.face_encodings(biden_image)[0]
tiempo_encoding.append(time.time() - inicio_tiempo)
inicio_tiempo = time.time()
obama_face_encoding = face_recognition.face_encodings(obama_image)[0]
tiempo_encoding.append(time.time() - inicio_tiempo)
inicio_tiempo = time.time()
unknown_face_encoding = face_recognition.face_encodings(unknown_image)[0]
tiempo_encoding.append(time.time() - inicio_tiempo)
inicio_tiempo = time.time()
    
print(f"Tiempo promedio de encoding: {np.mean(tiempo_encoding)}")
# Out:
# Tiempo promedio de encoding: 2.6360719203948975

# %%
print(biden_face_encoding)
print(obama_face_encoding)
print(unknown_face_encoding)
# Out:
# [ 0.00212634  0.18151696  0.08942953 -0.02890662 -0.13226929  0.04053921
#  -0.03351216 -0.07746185  0.05412482 -0.05690686  0.24183109 -0.05402808
#  -0.25743544 -0.05157363  0.06138313  0.12605764 -0.14946274 -0.06552805
#  -0.20102572 -0.06235627 -0.01103389 -0.0410016   0.02593715 -0.07272571
#  -0.20662072 -0.23533899 -0.04712093 -0.1022827  -0.02789485 -0.16243912
#   0.07824211 -0.03084383 -0.14441712 -0.05164247 -0.04710121 -0.0298584
#  -0.01722826 -0.05847342  0.13154459  0.0262634  -0.17892288  0.13025905
#   0.0073351   0.21587208  0.29474819 -0.00523595  0.04717013 -0.08853557
#   0.13626243 -0.24181861  0.05437332  0.03498961  0.16807069  0.05769813
#   0.14244418 -0.0731723   0.02392231  0.18972901 -0.200625    0.03737672
#   0.05043876 -0.05482149  0.03411502 -0.04349234  0.12301472  0.11024218
#  -0.009777   -0.09036201  0.19369094 -0.09519793 -0.11277228  0.03078757
#  -0.06616243 -0.12772179 -0.33526269  0.00107876  0.27036449  0.1360216
#  -0.29611111 -0.07562292 -0.04549194  0.00518049  0.03369439  0.00834185
#  -0.03430053 -0.13692579 -0.05488759 -0.01437558  0.24373633 -0.10935871
#   0.00704367  0.22373417  0.04802165 -0.14844172  0.05571177 -0.03593142
#  -0.11785192 -0.01510648 -0.1176923  -0.05191775 -0.0226258  -0.1587825
#  -0.03008005  0.0665701  -0.26241189  0.16402586 -0.01417352 -0.07986997
#  -0.05631709 -0.04092155  0.01244701  0.06576453  0.22907118 -0.24998775
#   0.20107335  0.22818169 -0.05759405  0.07731683  0.01206532  0.06270912
#  -1.52986825e-01 -2.16916889e-01 -2.06395462e-01  6.82107210e-02
#   3.23446095e-01  1.77454144e-01 -1.97833598e-01  8.60146657e-02
#  -1.61822855e-01  2.36844514e-02  4.61579300e-02 -8.01831298e-03
#  -7.09614456e-02 -7.60056674e-02 -4.69314568e-02  6.06513843e-02
#   9.88939703e-02  5.64718805e-02 -1.02547742e-02  2.46464521e-01
#  -6.91033155e-02  1.26198148e-02  4.18577269e-02  2.08157152e-02
#  -1.62669048e-01 -1.60740558e-02 -1.21763222e-01 -8.47118124e-02
#   6.62831515e-02 -6.04587272e-02  7.21929735e-03  1.00514866e-01
#  -2.17153475e-01  1.32877573e-01 -3.80835570e-02  1.30631961e-04
#   4.48988713e-02  5.67616411e-02 -9.51900706e-02 -2.85247099e-02
#   1.03198126e-01 -2.51681030e-01  2.17632413e-01  2.16781870e-01
#   2.77376529e-02  1.93441629e-01  8.80715549e-02  6.29435256e-02
#  -1.79621130e-02  1.27160763e-02 -1.75321162e-01 -6.55242428e-02
#   3.21264602e-02  3.11213732e-02  9.15245786e-02  9.49364528e-03]

# %%
known_faces = [
    biden_face_encoding,
    obama_face_encoding
]

# results is an array of True/False telling if the unknown face matched anyone in the known_faces array
inicio_tiempo = time.time()
results = face_recognition.compare_faces(known_faces, unknown_face_encoding)
elapsed_time = time.time() - inicio_tiempo
print(f"Tiempo de comparacion: {elapsed_time}")

print("Is the unknown face a picture of Biden? {}".format(results[0]))
print("Is the unknown face a picture of Obama? {}".format(results[1]))
print("Is the unknown face a new person that we've never seen before? {}".format(not True in results))
# Out:
# Tiempo de comparacion: 0.00021147727966308594
# Is the unknown face a picture of Biden? False
# Is the unknown face a picture of Obama? True
# Is the unknown face a new person that we've never seen before? False

# %%
for i in np.arange(0, 1.1, 0.1):
    inicio_tiempo = time.time()
    results = face_recognition.compare_faces(known_faces, unknown_face_encoding, i)
    elapsed_time = time.time() - inicio_tiempo
    print(f"Tiempo de comparacion: {elapsed_time} para i = {i}")
    print(results)
# Out:
# Tiempo de comparacion: 0.00012254714965820312 para i = 0.0
# [np.False_, np.False_]
# Tiempo de comparacion: 0.0001442432403564453 para i = 0.1
# [np.False_, np.False_]
# Tiempo de comparacion: 4.649162292480469e-05 para i = 0.2
# [np.False_, np.False_]
# Tiempo de comparacion: 3.24249267578125e-05 para i = 0.30000000000000004
# [np.False_, np.False_]
# Tiempo de comparacion: 4.601478576660156e-05 para i = 0.4
# [np.False_, np.True_]
# Tiempo de comparacion: 2.86102294921875e-05 para i = 0.5
# [np.False_, np.True_]
# Tiempo de comparacion: 2.7418136596679688e-05 para i = 0.6000000000000001
# [np.False_, np.True_]
# Tiempo de comparacion: 2.8133392333984375e-05 para i = 0.7000000000000001
# [np.False_, np.True_]
# Tiempo de comparacion: 2.5987625122070312e-05 para i = 0.8
# [np.False_, np.True_]
# Tiempo de comparacion: 2.6702880859375e-05 para i = 0.9
# [np.True_, np.True_]
# Tiempo de comparacion: 2.6464462280273438e-05 para i = 1.0
# [np.True_, np.True_]

# %%
face_recognition.face_distance(known_faces, unknown_face_encoding)
# Out:
# array([0.8158405 , 0.34573498])

# %%
face_recognition.face_landmarks(biden_image)
# Out:
# [{'chin': [(429, 328),
#    (426, 368),
#    (424, 408),
#    (425, 447),
#    (437, 484),
#    (460, 515),
#    (490, 538),
#    (524, 556),
#    (562, 564),
#    (600, 566),
#    (630, 554),
#    (655, 533),
#    (672, 507),
#    (684, 476),
#    (694, 445),
#    (702, 413),
#    (707, 382)],
#   'left_eyebrow': [(488, 294), (509, 279), (535, 278), (561, 283), (584, 296)],
#   'right_eyebrow': [(622, 307),
#    (646, 305),
#    (670, 309),
#    (691, 321),
#    (698, 344)],
#   'nose_bridge': [(601, 328), (599, 352), (598, 375), (596, 400)],
#   'nose_tip': [(555, 414), (570, 421), (586, 428), (601, 428), (614, 426)],
#   'left_eye': [(512, 320),
#    (528, 316),
#    (544, 319),
#    (557, 331),
#    (541, 330),
#    (525, 327)],
#   'right_eye': [(629, 348),
#    (647, 342),
#    (661, 346),
#    (672, 357),
#    (659, 358),
#    (644, 354)],
#   'top_lip': [(519, 459),
#    (545, 455),
#    (566, 456),
#    (580, 462),
#    (595, 462),
#    (610, 470),
#    (627, 480),
#    (620, 477),
#    (593, 470),
#    (579, 468),
#    (564, 463),
#    (527, 459)],
#   'bottom_lip': [(627, 480),
#    (606, 482),
#    (589, 479),
#    (575, 477),
#    (560, 473),
#    (540, 468),
#    (519, 459),
#    (527, 459),
#    (563, 461),
#    (577, 466),
#    (592, 468),
#    (620, 477)]}]

# %%
import json
import pprint
face_landmarks_list=face_recognition.face_landmarks(biden_image)
formatted_data = pprint.pformat(face_landmarks_list, indent=2, width=80)
print(formatted_data)
# Out:
# [ { 'bottom_lip': [ (627, 480),
#                     (606, 482),
#                     (589, 479),
#                     (575, 477),
#                     (560, 473),
#                     (540, 468),
#                     (519, 459),
#                     (527, 459),
#                     (563, 461),
#                     (577, 466),
#                     (592, 468),
#                     (620, 477)],
#     'chin': [ (429, 328),
#               (426, 368),
#               (424, 408),
#               (425, 447),
#               (437, 484),
#               (460, 515),
#               (490, 538),
#               (524, 556),
#               (562, 564),
#               (600, 566),
#               (630, 554),
#               (655, 533),
#               (672, 507),
#               (684, 476),
#               (694, 445),
#               (702, 413),
#               (707, 382)],
#     'left_eye': [ (512, 320),
#                   (528, 316),
#                   (544, 319),
#                   (557, 331),
#                   (541, 330),
#                   (525, 327)],
#     'left_eyebrow': [ (488, 294),
#                       (509, 279),
#                       (535, 278),
#                       (561, 283),
#                       (584, 296)],
#     'nose_bridge': [(601, 328), (599, 352), (598, 375), (596, 400)],
#     'nose_tip': [(555, 414), (570, 421), (586, 428), (601, 428), (614, 426)],
#     'right_eye': [ (629, 348),
#                    (647, 342),
#                    (661, 346),
#                    (672, 357),
#                    (659, 358),
#                    (644, 354)],
#     'right_eyebrow': [ (622, 307),
#                        (646, 305),
#                        (670, 309),
#                        (691, 321),
#                        (698, 344)],
#     'top_lip': [ (519, 459),
#                  (545, 455),
#                  (566, 456),
#                  (580, 462),
#                  (595, 462),
#                  (610, 470),
#                  (627, 480),
#                  (620, 477),
#                  (593, 470),
#                  (579, 468),
#                  (564, 463),
#                  (527, 459)]}]

# %%
plt.figure(figsize=(30, 18))
plt.imshow(biden_image)
for landmarks in face_landmarks_list:
    for facial_feature, points in landmarks.items():
        x = [p[0] for p in points]
        y = [p[1] for p in points]
        plt.scatter(x, y, s=10, c="lime", label=facial_feature)  # Puntos en color verde lima

plt.axis("off")  # Ocultar los ejes
plt.show()
